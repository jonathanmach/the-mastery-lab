# %% [markdown]
# # Docker SDK for Python Exploration
# https://docker-py.readthedocs.io/en/stable/index.html
#
#
# # Instantiating a Client
# To talk to a Docker daemon, you first need to instantiate a client. You can use from_env() to connect using the default socket or the configuration in your environment:

# %%
import docker
import os

# set DOCKER_HOST env variable if needed (eg: using colima on macOS)
os.environ['DOCKER_HOST'] = 'unix:///Users/jonathan/.colima/default/docker.sock'

client = docker.from_env()

for container in client.containers.list():
    print(container.name)
